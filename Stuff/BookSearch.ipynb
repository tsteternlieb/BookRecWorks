# %% [markdown]
# ## File for searching book recomendations
# Recommendations are not based on overall ratings, but potentially should be

# %%
torch.hub.load_state_dict_from_url('')

# %%
import re, json, requests

# %%
url = 'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/book_to_int.json'
resp = requests.get(url)
data = json.loads(resp.text)

# %%
data
# Out:
# {'Magician': 1,
#  'Perfect': 2,
#  'The Lost Wife': 3,
#  'Among the Impostors (Shadow Children, #2)': 4,
#  'Lord Edgware Dies': 5,
#  'Star Wars: Lost Stars': 6,
#  'Villa Incognito': 7,
#  "The Devil's Punchbowl": 8,
#  'Desire Unchained (Shadow Lover)': 9,
#  'Sunset': 10,
#  'In Flight': 11,
#  'Reckless': 12,
#  'Sherlock Holmes: The Complete Novels and Stories, Volume I': 13,
#  'Empire Falls': 14,
#  'Clean Sweep': 15,
#  'The Hotel New Hampshire': 16,
#  'Omertà': 17,
#  'The Spirit Catches You and You Fall Down: A Hmong Child, Her American Doctors, and the Collision of Two Cultures': 18,
#  'When He was Wicked': 19,
#  'The English Spy': 20,
#  'Saving Grace': 21,
#  "Prince's Gambit": 22,
#  'Chasing Perfect': 23,
#  'L.A. Confidential': 24,
#  'Jonathan Strange & Mr Norrell': 25,
#  'The Secret History': 26,
#  'The Authoritative Calvin and Hobbes': 27,
#  'Dom Casmurro': 28,
#  'The Beauty Myth: How Images of Beauty Are Used Against Women': 29,
#  'Harvest ': 30,
#  "A Room of One's Own": 31,
#  'Sweethearts': 32,
#  'The Closers': 33,
#  'Nine Stories': 34,
#  'The Obelisk Gate': 35,
#  'O Homem Duplicado': 36,
#  'The Annotated Sherlock Holmes': 37,
#  'Leven Thumps and the Eyes of the Want (Leven Thumps, #3)': 38,
#  'Olympos': 39,
#  'Only the Good Spy Young': 40,
#  'Rainbow Six': 41,
#  'On the Road': 42,
#  'How the Grinch Stole Christmas!': 43,
#  "The Skin I'm In": 44,
#  'Selected Poems of Emily Dickinson': 45,
#  'Match Me If You Can': 46,
#  'Pursuit of Honor': 47,
#  'Edvard Munch': 48,
#  'Welcome to the World, Baby Girl!': 49,
#  'The Stepford Wives': 50,
#  'The Twentieth Wife': 51,
#  'Among the Betrayed': 52,
#  'I Too Had A Love Story': 53,
#  'Prentice Alvin (Tales of Alvin Maker #3)': 54,
#  'North of Beautiful': 55,
#  'The Ring of Solomon': 56,
#  'Apathy and Other Small Victories': 57,
#  'Black List': 58,
#  'Skin': 59,
#  'Body of Evidence ': 60,
#  'Judge & Jury': 61,
#  'Writing Down the Bones: Freeing the Writer Within': 62,
#  "Caliban's War": 63,
#  'Rodrick Rules': 64,
#  'Creation in Death ': 65,
#  'Meditationes de prima philosophia': 66,
#  'Darkfever': 67,
#  'Shades of Earth': 68,
#  'Old School': 69,
#  'Beloved': 70,
#  'My Lady Jane': 71,
#  'Sweetbitter': 72,
#  'The Jester': 73,
#  'Sorgenfri': 74,
#  'Hyperspace: A Scientific Odyssey Through Parallel Universes, Time Warps, and the Tenth Dimension': 75,
#  'A Lick of Frost': 76,
#  'The Cider House Rules': 77,
#  'The Book of Ruth': 78,
#  'Oblivion': 79,
#  'Outlander': 80,
#  'Eiger Dreams: Ventures Among Men and Mountains': 81,
#  'Also sprach Zarathustra': 82,
#  'The Secret Life of Bees': 83,
#  'Fences (The Century Cycle #6)': 84,
#  'Rising Tides (Chesapeake Bay Saga #2)': 85,
#  'Influx': 86,
#  'False Impression': 87,
#  'Succubus Heat': 88,
#  'My Year of Meats': 89,
#  'Bury Your Dead': 90,
#  'Tithe: A Modern Faerie Tale ': 91,
#  'Las batallas en el desierto': 92,
#  'Because of Low': 93,
#  'キスよりも早く1': 94,
#  'The Death and Life of Charlie St. Cloud': 95,
#  'Each Peach Pear Plum': 96,
#  'Preacher Vol. 1: Gone to Texas': 97,
#  'The Tell-Tale Heart': 98,
#  'Any Human Heart': 99,
#  'Analfabeten som kunde räkna': 100,
#  'The Edible Woman': 101,
#  'Four: A Divergent Collection': 102,
#  'Πολιτεία': 103,
#  'A Farewell to Arms': 104,
#  'Panda Bear, Panda Bear, What Do You See?': 105,
#  'Kings Rising': 106,
#  'Ticktock': 107,
#  'El túnel': 108,
#  'The Queen': 109,
#  'Short Stories from Hogwarts of Heroism, Hardship and Dangerous Hobbies': 110,
#  'The Perfect Hope': 111,
#  'The Secret': 112,
#  'Desires of the Dead': 113,
#  'Food: A Love Story': 114,
#  'Sons of Fortune': 115,
#  'Zita the Spacegirl': 116,
#  'Flyboys: A True Story of Courage': 117,
#  'Del amor y otros demonios': 118,
#  'How I Raised Myself from Failure to Success in Selling': 119,
#  'Wool 2: Proper Gauge': 120,
#  'Storm Prey': 121,
#  'The Return of the King': 122,
#  'Spider Bones': 123,
#  'The Rosie Project': 124,
#  'アンダーグラウンド [Andāguraundo]': 125,
#  'Die Henkerstochter (Band 1 aus der Reihe "Die Henkerstochter-Saga)': 126,
#  'Good Night, Mr. Tom': 127,
#  'The Rest of Us Just Live Here': 128,
#  'The Last Runaway': 129,
#  'Physics of the Impossible: A Scientific Exploration of the World of Phasers, Force Fields, Teleportation, and Time Travel': 130,
#  'Dragondrums (Pern: Harper Hall, #3)': 131,
#  '易 [Yì]': 132,
#  'Junky': 133,
#  'You Shall Know Our Velocity!': 134,
#  'Feral Sins': 135,
#  'Stuff White People Like: the Definitive Guide to the Unique Taste of Millions': 136,
#  'White Fang': 137,
#  'Keeping You a Secret': 138,
#  'The Spellman Files': 139,
#  'A Better World': 140,
#  "School's Out Forever": 141,
#  'The Vor Game': 142,
#  'Lyle, Lyle, Crocodile (Lyle the Crocodile)': 143,
#  'How to Cook Everything Vegetarian: Simple Meatless Recipes for Great Food': 144,
#  'The Little Friend': 145,
#  'The One Tree': 146,
#  'Practical Magic': 147,
#  'Howl and Other Poems ': 148,
#  '2BR02B': 149,
#  'Burning For Revenge': 150,
#  'Krew elfów': 151,
#  'Walk Two Moons': 152,
#  'The Complete Poems of Emily Dickinson': 153,
#  'The Power of a Praying Wife': 154,
#  'The Suspicions of Mr. Whicher: Murder and the Undoing of a Great Victorian Detective': 155,
#  'Snowflake Bentley (Caldecott Medal Book)': 156,
#  'The Automatic Millionaire: A Powerful One-Step Plan to Live and Finish Rich': 157,
#  'As Sure as the Dawn (Mark of the Lion, #3)': 158,
#  'Tobacco Road': 159,
#  'Eat And Run': 160,
#  "A Child's Garden of Verses": 161,
#  "Alex Cross's Trial": 162,
#  'Etiquette & Espionage': 163,
#  'Innocence': 164,
#  'The Rise of Theodore Roosevelt ': 165,
#  'Cinder': 166,
#  'Den vita lejoninnan': 167,
#  'The Days Are Just Packed: A Calvin and Hobbes Collection': 168,
#  'Falling Angels': 169,
#  'The Collector': 170,
#  'Black Boy: A Record of Youth and Childhood': 171,
#  "Methuselah's Children": 172,
#  'The Codex': 173,
#  'Out of the Dark ': 174,
#  'The submissive': 175,
#  'Hellboy: The Chained Coffin and Others': 176,
#  'Out of the Easy': 177,
#  'Hannibal Rising': 178,
#  'A Clockwork Orange': 179,
#  'Blackout': 180,
#  'I Am Half-Sick of Shadows ': 181,
#  "Elle s'appelait Sarah": 182,
#  'The Assassin and the Empire': 183,
#  "Love the One You're With": 184,
#  'Broken Angels': 185,
#  'The Deep End of the Ocean': 186,
#  'Seduce Me at Sunrise': 187,
#  'Reached': 188,
#  'Bergdorf Blondes': 189,
#  'Overruled': 190,
#  'Starter for Ten': 191,
#  'The Pillars of Creation': 192,
#  'Little Brother': 193,
#  'The Satanic Verses': 194,
#  "Finger Lickin' Fifteen": 195,
#  'I Have Lived A Thousand Years: Growing Up In The Holocaust': 196,
#  "Kushiel's Dart": 197,
#  'I Am Not A Serial Killer (John Cleaver, #1)': 198,
#  'Web of Lies': 199,
#  'Storia del nuovo cognome': 200,
#  "The Dirt: Confessions of the World's Most Notorious Rock Band": 201,
#  'Один день Ивана Денисовича': 202,
#  'Some Girls Bite': 203,
#  'Prisoner of my desire ': 204,
#  'The Omen Machine (Richard and Kahlan, #1)': 205,
#  'Endgame: The Calling': 206,
#  '青の祓魔師 2': 207,
#  'I Hope They Serve Beer in Hell': 208,
#  'Abhorsen': 209,
#  'A Painted House': 210,
#  'True Believer': 211,
#  'Where Men Win Glory: The Odyssey of Pat Tillman': 212,
#  'No Logo': 213,
#  "Lamb: The Gospel According to Biff, Christ's Childhood Pal": 214,
#  'Ramona the Brave ': 215,
#  'The Sweet Far Thing': 216,
#  'The Matlock Paper': 217,
#  "Good to Great: Why Some Companies Make the Leap... and Others Don't": 218,
#  'Stranger Than Fiction: True Stories': 219,
#  'The Book of Joe': 220,
#  'Lies My Teacher Told Me : Everything Your American History Textbook Got Wrong': 221,
#  'Checkmate (A Neighbor from Hell, #3)': 222,
#  'Entice': 223,
#  'The Alchemyst: The Secrets of The Immortal Nicholas Flamel': 224,
#  'Art in Theory, 1900-2000: An Anthology of Changing Ideas': 225,
#  'Norse Mythology': 226,
#  'Fablehaven: Secrets of the Dragon Sanctuary (Fablehaven, #4)': 227,
#  'Sun and Moon, Ice and Snow': 228,
#  "Hell's Angels": 229,
#  'First Family': 230,
#  'Sadako and the Thousand Paper Cranes': 231,
#  'Astérix le Gaulois': 232,
#  'The Minority Report': 233,
#  'Dark Demon (Carpathians, #16)': 234,
#  'My Lobotomy': 235,
#  'Nine Parts of Desire: The Hidden World of Islamic Women': 236,
#  "Cat's Eye": 237,
#  'The Post-Birthday World ': 238,
#  'Push': 239,
#  'Way Station': 240,
#  'Starless Night (Legacy of the Drow #2)': 241,
#  'The Scarlet Feather': 242,
#  "I'll Give You the Sun": 243,
#  'The Strange Case of Dr. Jekyll and Mr. Hyde and Other Tales of Terror ': 244,
#  'Les Misérables': 245,
#  'Side Jobs: Stories From The Dresden Files': 246,
#  'Death du Jour': 247,
#  'Wintersmith': 248,
#  'Fear of Flying': 249,
#  'Angle of Repose': 250,
#  'Blood Song': 251,
#  'Presentation Zen: Simple Ideas on Presentation Design and Delivery (Voices That Matter)': 252,
#  'The Luminaries': 253,
#  'Taken': 254,
#  'Grim Tuesday': 255,
#  'Blood Work': 256,
#  'Son of a Witch': 257,
#  'Arrows of the Queen (Heralds of Valdemar #1)': 258,
#  'The Enemy': 259,
#  'Lover Enshrined, part one': 260,
#  'Half Asleep in Frog Pajamas': 261,
#  'Black House ': 262,
#  'The Melancholy Death of Oyster Boy and Other Stories': 263,
#  'The Crossing': 264,
#  'A Caribbean Mystery': 265,
#  'El prisionero del cielo': 266,
#  'Anatomy of the Spirit: The Seven Stages of Power and Healing': 267,
#  'Birdsong': 268,
#  'Unless': 269,
#  'South of Broad': 270,
#  'Pretties': 271,
#  'Дядя Ваня': 272,
#  'Lies Women Believe: And the Truth that Sets Them Free': 273,
#  "In Search of Schrödinger's Cat : Quantum Physics And Reality": 274,
#  'Tintentod': 275,
#  'The 3 Mistakes of My Life': 276,
#  'Paranormalcy': 277,
#  'The Time Machine': 278,
#  'Everything We Keep': 279,
#  'Gulp: Adventures on the Alimentary Canal': 280,
#  'A Theory of Justice': 281,
#  'بنات الرياض': 282,
#  'Lonesome Dove': 283,
#  'The Unusual Suspects': 284,
#  'Learned Optimism: How to Change Your Mind and Your Life': 285,
#  'The Story of Art': 286,
#  'Janet Evanovich Three and Four Two-Book Set (Stephanie Plum, #3-4)': 287,
#  'In a People House': 288,
#  'The Wounded Land': 289,
#  'The Thirty-Nine Steps': 290,
#  'One Thousand Gifts': 291,
#  'Starlight (Warriors: The New Prophecy, #4)': 292,
#  'The Complete Tales and Poems of Edgar Allan Poe': 293,
#  'Τὰ εἰς ἑαυτόν ': 294,
#  'The End of Your Life Bookclub': 295,
#  'Easy': 296,
#  'A Court of Mist and Fury': 297,
#  'Princess in Love': 298,
#  'Gorky Park': 299,
#  'Scat': 300,
#  'Gemeinsames Leben': 301,
#  "My Sister's Keeper": 302,
#  'Fallen in Love': 303,
#  'The Grand Sophy': 304,
#  'Kick-Ass': 305,
#  'The Mating': 306,
#  'Grip of the Shadow Plague': 307,
#  'A Fistful of Charms': 308,
#  "Beauty's Release (Sleeping Beauty, #3)": 309,
#  "Gabriel's Rapture": 310,
#  'The Merchant of Venice': 311,
#  'China Rich Girlfriend': 312,
#  "Cleopatra's Daughter": 313,
#  'The Elves of Cintra ': 314,
#  'Last Exit to Brooklyn': 315,
#  "Magic's Pawn": 316,
#  'Black Hawk Down': 317,
#  "Martha Stewart's Cupcakes: 175 Inspired Ideas for Everyone's Favorite Treats": 318,
#  'Chosen: A House of Night Novel': 319,
#  'One Day': 320,
#  'The Howling': 321,
#  "Six's Legacy": 322,
#  'Fool Me Once': 323,
#  'Teardrop': 324,
#  'Soul of the Fire': 325,
#  'Breath': 326,
#  'Put Me in the Zoo': 327,
#  "There's a Wocket in My Pocket": 328,
#  'The Dirty Girls Social Club': 329,
#  'Triptych': 330,
#  'Sea of Poppies': 331,
#  'Erections, Ejaculations, Exhibitions and General Tales of Ordinary Madness': 332,
#  'Exit to Eden': 333,
#  'Look Homeward, Angel': 334,
#  'A Hundred Summers': 335,
#  'The Ice Twins': 336,
#  'The Girl With No Past': 337,
#  'The Three': 338,
#  'Purity in Death': 339,
#  'Seconds: A Graphic Novel': 340,
#  'The Illustrated Mum': 341,
#  'Small Sacrifices: A True Story of Passion and Murder': 342,
#  'A Single Shard': 343,
#  'One Breath Away': 344,
#  'Cooked: A Natural History of Transformation ': 345,
#  'Star Wars: The Force Awakens': 346,
#  'Royal Blood (Vampire Kisses, #6)': 347,
#  'Hell House': 348,
#  'The Bookseller': 349,
#  "Ender's Shadow": 350,
#  'Nostromo: a Tale of the Seaboard': 351,
#  'The Private Patient': 352,
#  'The First Phone Call from Heaven': 353,
#  'Blood, Bones and Butter: The Inadvertent Education of a Reluctant Chef': 354,
#  'Ancestors of Avalon ': 355,
#  "The Devil's Alternative": 356,
#  'Audrey Rose': 357,
#  'The Five Chinese Brothers': 358,
#  '"حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية': 359,
#  'Rage of a Demon King (The Serpentwar Saga #3)': 360,
#  'Beyond the Grave (The 39 Clues, #4)': 361,
#  'Tehanu': 362,
#  'Wuthering Heights': 363,
#  'Such a Pretty Girl': 364,
#  'Music of the Heart': 365,
#  'Twilight Eyes': 366,
#  'Gang Leader for a Day': 367,
#  'Left Drowning': 368,
#  'Wish You Well': 369,
#  'Slapstick': 370,
#  'Survivor': 371,
#  'Mythologies': 372,
#  'Tigana': 373,
#  'Committed: A Skeptic Makes Peace with Marriage': 374,
#  'Plum Spooky': 375,
#  'Ghost Town': 376,
#  'One Fifth Avenue': 377,
#  'Honolulu': 378,
#  'In Watermelon Sugar': 379,
#  'The ABC Murders': 380,
#  'The Man Who Listens to Horses': 381,
#  'A Severe Mercy': 382,
#  'Faith of the Fallen  (Sword of Truth, #6)': 383,
#  'Breakfast of Champions': 384,
#  'Hand, Hand, Fingers, Thumb': 385,
#  'Battlefield of the Mind: Winning the Battle in Your Mind': 386,
#  'Scandal in Spring': 387,
#  'Benjamin Franklin: An American Life': 388,
#  'Bluebeard': 389,
#  'A Room with a View': 390,
#  'A Million Suns ': 391,
#  'Labyrinths': 392,
#  "Don't Let's Go to the Dogs Tonight: An African Childhood": 393,
#  'The Aquitaine Progression': 394,
#  'The Third Victim': 395,
#  '会長はメイド様! 2': 396,
#  'The River': 397,
#  'The Descendants': 398,
#  'The Vow: The Kim and Krickitt Carpenter Story': 399,
#  'Beautiful Creatures': 400,
#  'Friends and Lovers': 401,
#  'Long Lost': 402,
#  'Bright Shiny Morning': 403,
#  'Pivot Point': 404,
#  'The Great Train Robbery': 405,
#  'The Lewis Man': 406,
#  "The Liars' Club: A Memoir": 407,
#  'Lexicon': 408,
#  'The Shelters of Stone': 409,
#  'The Woman in White': 410,
#  'Paint It Black': 411,
#  'House of Many Ways': 412,
#  'Valis': 413,
#  'A Fish Out of Water': 414,
#  'The Unwritten, Volume 1: Tommy Taylor and the Bogus Identity': 415,
#  'Fearless (The Lost Fleet, #2)': 416,
#  'Lock In': 417,
#  'Deadeye Dick': 418,
#  'Sh*t My Dad Says': 419,
#  'People of the Book': 420,
#  'Edge of Eternity': 421,
#  'Whitethorn Woods': 422,
#  'Body Movers ': 423,
#  'Parallel Worlds: A Journey Through Creation, Higher Dimensions, and the Future of the Cosmos': 424,
#  'The House of Silk': 425,
#  'The Necromancer: The Secrets of The Immortal Nicholas Flamel': 426,
#  'Juliet': 427,
#  'Master of the Senate': 428,
#  'The Last Olympian': 429,
#  'The Darkest Road': 430,
#  'No Place to Hide: Edward Snowden, the NSA, and the U.S. Surveillance State': 431,
#  'The Sandman: Season of Mists': 432,
#  'The Wordy Shipmates': 433,
#  'Last Man Standing': 434,
#  'Discours de la Méthode suivi de Méditations Métaphysiques': 435,
#  "Einstein's Dreams": 436,
#  'The Hydrogen Sonata': 437,
#  'Skin Tight': 438,
#  'Addicted': 439,
#  'On the Island': 440,
#  '神様はじめました 1': 441,
#  'The Goal': 442,
#  "Having Our Say: The Delany Sisters' First 100 Years": 443,
#  "Exile's Return": 444,
#  'Bloodrose': 445,
#  'Splendor': 446,
#  'Frost Burned': 447,
#  'The Five Dysfunctions of a Team': 448,
#  'What She Left Behind': 449,
#  'This is Water': 450,
#  'UnDivided': 451,
#  'Bad Monkey': 452,
#  'The Wind Singer': 453,
#  'East': 454,
#  'The Princess Bride': 455,
#  'The Redemption of Callie & Kayden': 456,
#  'The Chosen': 457,
#  'Random Family: Love, Drugs, Trouble, and Coming of Age in the Bronx': 458,
#  'On the Beach': 459,
#  'True Love Story': 460,
#  ' Игрок ': 461,
#  'Griffin & Sabine: An Extraordinary Correspondence': 462,
#  'The Fourth Estate': 463,
#  'The Alibi': 464,
#  'Ramona the Pest': 465,
#  'Dark Rivers of the Heart': 466,
#  'Madame Bovary': 467,
#  'Night of the Living Dummy': 468,
#  'Means of Ascent ': 469,
#  'Le Scaphandre et le Papillon': 470,
#  'Der Steppenwolf: Erzählung': 471,
#  'Sherlock Holmes: The Complete Novels and Stories, Vol 2': 472,
#  'The Road to Character': 473,
#  "Dumplin'": 474,
#  'شكلها باظت': 475,
#  'I Hunt Killers': 476,
#  'Tai-Pan': 477,
#  'Wise Blood': 478,
#  'Lemony Snicket: The Unauthorized Autobiography': 479,
#  'Astonishing X-Men, Volume 2: Dangerous': 480,
#  'Charlie Bone and the Beast (The Children of the Red King, # 6)': 481,
#  'A Bite to Remember': 482,
#  'La planète des singes': 483,
#  'The Empty Chair ': 484,
#  'Lothaire': 485,
#  'Crooked House': 486,
#  'Ghost World': 487,
#  'Scott Pilgrim, Volume 4: Scott Pilgrim Gets It Together': 488,
#  'The Beatles: The Biography': 489,
#  'Fire': 490,
#  'Batman & Robin: Batman Reborn': 491,
#  'The Great Brain': 492,
#  'Back on Blossom Street': 493,
#  "Wizard's First Rule": 494,
#  'Euphoria': 495,
#  'The Surgeon of Crowthorne: a tale of murder, madness & the love of words': 496,
#  'Shades of Midnight': 497,
#  'The Good Girl': 498,
#  "Beauty's Punishment": 499,
#  'Memoria de mis putas tristes': 500,
#  'The Earth, My Butt, and Other Big Round Things': 501,
#  'Meet Samantha: An American Girl (American Girls: Samantha, #1)': 502,
#  'La Chartreuse de Parme': 503,
#  'Preach My Gospel (A Guide to Missionary Service)': 504,
#  'How to Save a Life': 505,
#  'Shotgun Lovesongs': 506,
#  'The Tale of the Body Thief': 507,
#  'Starcrossed': 508,
#  'Naked': 509,
#  'Summer Knight': 510,
#  'Washington Square': 511,
#  'Conspiracy in Death': 512,
#  'The Hobbit or There and Back Again': 513,
#  'The Twits': 514,
#  'Kinesen': 515,
#  'The Hating Game': 516,
#  'Mr. Perfect': 517,
#  'Wheat Belly: Lose the Wheat, Lose the Weight, and Find Your Path Back to Health ': 518,
#  'Broken Prey': 519,
#  'If You Take a Mouse to the Movies': 520,
#  'The Secret Garden': 521,
#  'Maximum Ride: The Manga, Vol. 1': 522,
#  'Inés del alma mía': 523,
#  'Darkest Powers Trilogy (Darkest Powers, #1-3)': 524,
#  'The Copper Beech': 525,
#  'A Good Man Is Hard to Find, and Other Stories': 526,
#  'The Secret Diary of Adrian Mole, Aged 13 3/4': 527,
#  'The Black Prism': 528,
#  "Clifford's Halloween (Clifford)": 529,
#  'Fairest': 530,
#  'Ride Steady': 531,
#  'Maus II : And Here My Troubles Began ': 532,
#  'The Heretic Queen': 533,
#  "Little Princes: One Man's Promise to Bring Home the Lost Children of Nepal": 534,
#  'Passing': 535,
#  'American Assassin': 536,
#  'Start with Why: How Great Leaders Inspire Everyone to Take Action': 537,
#  'A Kiss for Little Bear': 538,
#  'The 9th Judgment': 539,
#  'Hunger Makes Me a Modern Girl': 540,
#  'The Fiery Cross': 541,
#  'The Outsiders': 542,
#  'Almost Heaven': 543,
#  'For a Few Demons More ': 544,
#  'Siddhartha': 545,
#  'Dragonsong ': 546,
#  'Port Mortuary': 547,
#  'Chesapeake': 548,
#  'The Comfort of Strangers': 549,
#  "Nerilka's Story (Pern: Dragonriders of Pern, #5)": 550,
#  'The Art of Loving': 551,
#  'The School for Good and Evil': 552,
#  'The Valley of Amazement': 553,
#  "The Weed That Strings the Hangman's Bag": 554,
#  'Scorpia': 555,
#  'Worth Dying For': 556,
#  'Maitreyi': 557,
#  'The Stinky Cheese Man and Other Fairly Stupid Tales': 558,
#  'Drachenreiter': 559,
#  'The Power of Myth': 560,
#  "The King's Buccaneer": 561,
#  'Kitty and the Midnight Hour': 562,
#  'Generation X: Tales for an Accelerated Culture': 563,
#  'Rubicon: The Last Years of the Roman Republic': 564,
#  'The Ear, the Eye, and the Arm': 565,
#  "The Time Traveler's Wife": 566,
#  'The Iron Daughter': 567,
#  'Blood and Gold: The Vampire Marius': 568,
#  'Saving Faith': 569,
#  'Servant of the Bones': 570,
#  'Moby Dick; or, The Whale': 571,
#  'The Ship of Brides': 572,
#  'No Time for Goodbye': 573,
#  'Magonia': 574,
#  'An Instance of the Fingerpost': 575,
#  'A Map of the World': 576,
#  'The Dead-Tossed Waves ': 577,
#  'A Swiftly Tilting Planet': 578,
#  'The Peach Keeper ': 579,
#  'Gods in Alabama': 580,
#  "Gerald's Game": 581,
#  "It's Not About the Bike: My Journey Back to Life": 582,
#  'Sometimes Never': 583,
#  'In der Strafkolonie': 584,
#  'The Good, the Bad, and the Undead': 585,
#  'Who Will Cry When You Die? Life Lessons from the Monk Who Sold His Ferrari': 586,
#  'Secrets of a Summer Night': 587,
#  'Isprinsessan': 588,
#  'Mostly Harmless': 589,
#  'The Killing Dance (Anita Blake, Vampire Hunter, #6)': 590,
#  'Our Town: A Play in Three Acts': 591,
#  'The Bear and the Dragon': 592,
#  'Time for Bed': 593,
#  'Queen of Shadows': 594,
#  'Lunar Park': 595,
#  'What Alice Forgot': 596,
#  'The Complete Poems: Anne Sexton': 597,
#  'Mother of Pearl': 598,
#  'The Third Policeman': 599,
#  'The Healer': 600,
#  'The Happiness Project': 601,
#  'Mutiny on the Bounty': 602,
#  'The Will': 603,
#  'Carry On': 604,
#  'Hateship, Friendship, Courtship, Loveship, Marriage': 605,
#  "The Dark Elf Trilogy Collector's Edition (Forgotten Realms: Dark Elf Trilogy, #1-3)": 606,
#  'The Mystery of the Blue Train': 607,
#  'The Rivers of Zadaa': 608,
#  'The Emerald Atlas': 609,
#  'Batman: The Black Mirror': 610,
#  'Theodore Boone, Kid Lawyer': 611,
#  'An Old-Fashioned Girl': 612,
#  'Fantastic Voyage': 613,
#  'Filth': 614,
#  'How the Garcia Girls Lost Their Accents ': 615,
#  'Heartsick': 616,
#  'Seveneves': 617,
#  'Facing Your Giants: The God Who Made a Miracle Out of David Stands Ready to Make One Out of You': 618,
#  'The Silver Star': 619,
#  'Kiss of a Demon King ': 620,
#  'Cash: The Autobiography of Johnny Cash': 621,
#  'Brisingr': 622,
#  'What the Bleep Do We Know!?: Discovering the Endless Possibilities for Altering Your Everyday Reality': 623,
#  'Pride and Prejudice': 624,
#  'Pleasure of a Dark Prince ': 625,
#  'The Human Stain': 626,
#  'Frog And Toad Book Set: Frog And Toad Are Friends; Frog And Toad Together; Days With Frog And Toad; Frog And Toad All Year': 627,
#  'The Lions of Little Rock': 628,
#  'Sweet Filthy Boy ': 629,
#  'Into Thin Air: A Personal Account of the Mt. Everest Disaster': 630,
#  'The Shining Girls': 631,
#  'Winter in Madrid': 632,
#  'The Last Child': 633,
#  'The Soldiers of Halla': 634,
#  'Novecento': 635,
#  'The Teachings of Don Juan: A Yaqui Way of Knowledge': 636,
#  'Curtain: Poirot’s Last Case': 637,
#  'La Dame aux camélias': 638,
#  'To rise again at a decent hour': 639,
#  'Give and Take: A Revolutionary Approach to Success': 640,
#  'Runaway': 641,
#  'The Dot': 642,
#  'Touch the Dark': 643,
#  'Guardians of the West': 644,
#  'The Supernaturalist': 645,
#  "Lord Foul's Bane": 646,
#  'The Bronze Bow': 647,
#  'The Saggy Baggy Elephant (Little Golden Book)': 648,
#  'See Jane Score': 649,
#  'رباعیات [Robāʿiāt-e ʿOmar Khayyām]': 650,
#  'Care of the Soul : A Guide for Cultivating Depth and Sacredness in Everyday Life': 651,
#  'Hornet Flight': 652,
#  'オール・ユー・ニード・イズ・キル': 653,
#  'Spark': 654,
#  'Knit Two': 655,
#  'First Shift: Legacy': 656,
#  'Unraveling': 657,
#  'The Salmon of Doubt: Hitchhiking the Galaxy One Last Time': 658,
#  'Leviathan': 659,
#  'The Silkworm': 660,
#  'Jude the Obscure': 661,
#  "The Drunkard's Walk: How Randomness Rules Our Lives": 662,
#  'Between, Georgia': 663,
#  'The Namesake': 664,
#  "From Potter's Field": 665,
#  'The Guns of Navarone': 666,
#  'The Spectacular Now': 667,
#  'Krondor: The Betrayal': 668,
#  'Notes from a Big Country': 669,
#  'Take the Cannoli: Stories from the New World': 670,
#  'The Ringworld Engineers ': 671,
#  'Own the Wind': 672,
#  'Pygmalion and My Fair Lady (50th Anniversary Edition) (Signet Classics (Paperback))': 673,
#  'The Sandman: Overture': 674,
#  'Words of Radiance': 675,
#  'Revenge of the Wannabes (The Clique, #3)': 676,
#  'Dark Triumph (His Fair Assassin, #2)': 677,
#  'Girl in Translation': 678,
#  'Book of Shadows': 679,
#  "The Seven Principles for Making Marriage Work: A Practical Guide from the Country's Foremost Relationship Expert": 680,
#  'Na margem do rio Piedra eu sentei e chorei': 681,
#  'A Monstrous Regiment of Women': 682,
#  'Loving Mr. Daniels': 683,
#  'Among Others': 684,
#  'デスノート #6 (Desu Nōto) Kōkan (交換)': 685,
#  "Slaughterhouse-Five, or The Children's Crusade: A Duty-Dance with Death ": 686,
#  'Letter to My Daughter': 687,
#  'Some Luck': 688,
#  'Song of Susannah': 689,
#  "Twilight Director's Notebook": 690,
#  'Artemis Fowl Boxed Set (Artemis Fowl, #1-5)': 691,
#  'The Science of Getting Rich': 692,
#  'Rock Chick Rescue': 693,
#  'Telegraph Avenue': 694,
#  'The Masque of the Red Death': 695,
#  'Medium Raw: A Bloody Valentine to the World of Food and the People Who Cook': 696,
#  'The Red Garden': 697,
#  'The Gods of Mars': 698,
#  'A Girl of the Limberlost': 699,
#  'The Rainbow Comes and Goes: A Mother and Son On Life, Love, and Loss': 700,
#  'Free: The Future of a Radical Price': 701,
#  'Steal Like an Artist': 702,
#  'Punk 57': 703,
#  'The Art of Asking; or, How I Learned to Stop Worrying and Let People Help': 704,
#  'West Side Story': 705,
#  'Burnt Offerings (Anita Blake, Vampire Hunter, #7)': 706,
#  'Анна Каренина': 707,
#  'A Light in the Attic': 708,
#  'The Replacement': 709,
#  'Stay Close': 710,
#  'Habibi': 711,
#  'Mastery': 712,
#  'The Lying Game': 713,
#  'Takedown': 714,
#  'The Iron Queen': 715,
#  'Chicken Soup for the Soul': 716,
#  'Lit': 717,
#  'Memories of Midnight': 718,
#  'Before I Go to Sleep': 719,
#  'Burning Chrome and Other Stories': 720,
#  'Cards on the Table': 721,
#  'What Looks Like Crazy on an Ordinary Day': 722,
#  'The Pledge': 723,
#  'Summer People': 724,
#  'The Abyss': 725,
#  'Single White Vampire': 726,
#  'Way of the Peaceful Warrior: A Book That Changes Lives': 727,
#  'The Lost City of Faar': 728,
#  'Tenth of December': 729,
#  'Miles: The Autobiography': 730,
#  'The Red Tent': 731,
#  'The Illuminatus! Trilogy': 732,
#  'Black Elk Speaks': 733,
#  'Beautiful Bombshell': 734,
#  'The Sisterhood of the Traveling Pants': 735,
#  'Lassie Come-Home': 736,
#  'Reasonable Doubt': 737,
#  'Sycamore Row': 738,
#  'Night over Water': 739,
#  'Serafina and the Black Cloak': 740,
#  'Women': 741,
#  "Reaper's Gale": 742,
#  "I'd Tell You I Love You, But Then I'd Have to Kill You": 743,
#  'The Vacationers': 744,
#  'My Name Is Mary Sutter': 745,
#  'Nefes Nefese': 746,
#  'The Way of Kings, Part 1': 747,
#  'Where Rainbows End': 748,
#  'Cocktails for Three': 749,
#  'The Left Hand of God ': 750,
#  'Doll Bones': 751,
#  'Wrong': 752,
#  'Elephants Can Remember': 753,
#  'Double Star': 754,
#  'How Will You Measure Your Life?': 755,
#  'The Search': 756,
#  'The Oath of the Vayuputras': 757,
#  'The Time of My Life': 758,
#  'Forever Mine ': 759,
#  '1Q84 Book 3 [Ichi-kyū-hachi-yon]': 760,
#  'O Diário de um Mago': 761,
#  "The Traveler's Gift: Seven Decisions that Determine Personal Success": 762,
#  'Kindred in Death ': 763,
#  'Llama Llama Mad at Mama': 764,
#  'The Post-American World 2.0': 765,
#  'On the Fence': 766,
#  'The Rook': 767,
#  'Fire Sea': 768,
#  'The Yonahlossee Riding Camp for Girls': 769,
#  'Nine Princes in Amber': 770,
#  'Er ist wieder da': 771,
#  'The Demolished Man': 772,
#  'The Cronicle History of Henry the fift': 773,
#  'Rose Daughter': 774,
#  "The Millionaire Next Door: The Surprising Secrets of America's Wealthy": 775,
#  'Never Cry Wolf : The Amazing True Story of Life Among Arctic Wolves': 776,
#  'Blankets': 777,
#  'Snow Crash': 778,
#  'في قلبي أنثى عبرية': 779,
#  'Drown': 780,
#  "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again": 781,
#  'Veinte poemas de amor y una canción desesperada': 782,
#  'Saving June': 783,
#  'I Feel Bad About My Neck: And Other Thoughts on Being a Woman': 784,
#  'Underground Airlines': 785,
#  'The Return: Nightfall': 786,
#  'Beauty and the Beast': 787,
#  'The Shadow Throne': 788,
#  'Mήδεια': 789,
#  'The Hunger Games Box Set': 790,
#  'The Chronicles of Narnia': 791,
#  'Stones from the River': 792,
#  'Karin': 793,
#  'Lover at Last': 794,
#  'Nineteen Eighty-Four': 795,
#  'Safe Harbour': 796,
#  'Dreaming of You ': 797,
#  'The Case of Charles Dexter Ward': 798,
#  'Defending Jacob': 799,
#  'A Storm of Swords': 800,
#  'Tales of Caunterbury': 801,
#  'The Fire Next Time': 802,
#  'I Was Here': 803,
#  'Mort - playtext': 804,
#  'Forgive Me, Leonard Peacock': 805,
#  'Beautiful You': 806,
#  'Animal Speak: The Spiritual & Magical Powers of Creatures Great & Small': 807,
#  'The Stone Diaries': 808,
#  'One Foot in the Grave': 809,
#  'The Twilight Collection (Twilight, #1-3)': 810,
#  "It's In His Kiss": 811,
#  'Fables, Volume 8: Wolves': 812,
#  ' 国境の南、太陽の西 [Kokkyō no minami, taiyō no nishi]': 813,
#  'Close Encounters of the Third Kind': 814,
#  'To Kill a Mockingbird': 815,
#  'In the Woods': 816,
#  "The Mysterious Benedict Society and the Prisoner's Dilemma": 817,
#  'One False Note (The 39 Clues, Book 2)': 818,
#  'Everneath': 819,
#  "L'élégance du hérisson": 820,
#  ' Carry On, Warrior: Thoughts on Life Unarmed ': 821,
#  'A Drink Before the War': 822,
#  'The Jungle Books': 823,
#  'The Secret Agent: A Simple Tale': 824,
#  'House of Suns': 825,
#  'Live by Night': 826,
#  'The Famished Road': 827,
#  'The Crossing Places': 828,
#  'Second Glance': 829,
#  'A Prisoner of Birth': 830,
#  'The Little Red Hen (Little Golden Book)': 831,
#  'The Silent Wife': 832,
#  "I'll Walk Alone": 833,
#  'The Darkness That Comes Before': 834,
#  'Attack of the Deranged Mutant Killer Monster Snow Goons: A Calvin and Hobbes Collection': 835,
#  "Written in My Own Heart's Blood": 836,
#  'Virgin River': 837,
#  'Heart no Kuni no Alice  ': 838,
#  'I Am Pilgrim': 839,
#  'Sin City: A Dame to Kill For': 840,
#  'Back When We Were Grownups': 841,
#  'The Silver Chair': 842,
#  'The Lathe of Heaven': 843,
#  ' Daemon': 844,
#  'The Last Precinct': 845,
#  'Hard Choices': 846,
#  'A Gathering of Shadows': 847,
#  'Longbourn': 848,
#  'Sisters': 849,
#  'Financial Peace Revisited': 850,
#  'The Girl In The Ice': 851,
#  'My Side of the Mountain ': 852,
#  'Walden; or Life in the Woods': 853,
#  'That Old Cape Magic': 854,
#  'A Northern Light': 855,
#  'The Eternal Dawn': 856,
#  'Bite Club': 857,
#  'The Invisible Bridge': 858,
#  'Ex-Heroes': 859,
#  'Tortilla Flat': 860,
#  'Deadline': 861,
#  'A Court of Thorns and Roses': 862,
#  'Unbroken: A World War II Story of Survival, Resilience, and Redemption': 863,
#  'The Places That Scare You: A Guide to Fearlessness in Difficult Times': 864,
#  'The Stranger Beside Me': 865,
#  "His Majesty's Dragon": 866,
#  'Martin Eden': 867,
#  'Half a King': 868,
#  'Open City': 869,
#  'Batman: Earth One, Volume 1': 870,
#  'Waiting': 871,
#  'Brave New World': 872,
#  'Hardwired': 873,
#  'What Remains: A Memoir of Fate, Friendship, and Love': 874,
#  'Jinx': 875,
#  'The Case-Book of Sherlock Holmes': 876,
#  'Counting by 7s': 877,
#  'Truthwitch': 878,
#  'Bloodfever': 879,
#  'El coronel no tiene quién le escriba': 880,
#  'Big Cherry Holler (Big Stone Gap, Book 2)': 881,
#  'El Deafo': 882,
#  'The Forest House': 883,
#  'Heist Society': 884,
#  'Breakable': 885,
#  'Harry, A History: The True Story of a Boy Wizard, His Fans, and Life Inside the Harry Potter Phenomenon': 886,
#  'The Wonderful Story Of Henry Sugar And Six More': 887,
#  'Rough Country': 888,
#  'Les Liaisons dangereuses': 889,
#  'Legend of the Duck Commander': 890,
#  'The Dark Half': 891,
#  'The Misremembered Man': 892,
#  'The Third Wheel': 893,
#  'Sheep in a Jeep': 894,
#  'The World Is Flat: A Brief History of the Twenty-first Century': 895,
#  'After': 896,
#  'Divine Justice': 897,
#  'Fudge-a-Mania': 898,
#  'The Brass Verdict': 899,
#  'The Righteous Mind: Why Good People Are Divided by Politics and Religion': 900,
#  'Cold Days': 901,
#  'Go the Fuck to Sleep': 902,
#  'Scrappy Little Nobody': 903,
#  "I Don't Know How She Does It": 904,
#  "At Bertram's Hotel": 905,
#  'An Artist of the Floating World': 906,
#  'Misquoting Jesus: The Story Behind Who Changed the Bible and Why': 907,
#  'Remember Me?': 908,
#  'Singularity Sky': 909,
#  'The Forgetting Time': 910,
#  'The Diviners': 911,
#  'Genghis: Birth of an Empire': 912,
#  'Anthem': 913,
#  'Three Day Road': 914,
#  'The Book of Strange New Things': 915,
#  'Obsidian': 916,
#  'The Black Unicorn ': 917,
#  'Quidditch Through the Ages': 918,
#  'The Birth House': 919,
#  'Daring to Dream': 920,
#  'Post-Mortem:  A Mystery Introducing Dr. Kay Scarpetta': 921,
#  'The Old Curiosity Shop': 922,
#  'One More Chance': 923,
#  'Memoirs of a Geisha': 924,
#  'The Physician': 925,
#  'Your Heart Belongs to Me': 926,
#  '黒執事 III [Kuroshitsuji III]': 927,
#  'Maybe Not': 928,
#  'Emotional Intelligence': 929,
#  'Shakespeare: The World as Stage ': 930,
#  'Dust': 931,
#  'Nana': 932,
#  'The Demon King': 933,
#  'Empress Orchid': 934,
#  'Leviathan or The Matter, Forme and Power of a Common Wealth Ecclesiasticall and Civil': 935,
#  'The Secret Life of Violet Grant': 936,
#  'Sofies Verden': 937,
#  'The Souls of Black Folk': 938,
#  'El príncipe de la niebla': 939,
#  'Charlie and the Chocolate Factory': 940,
#  'The Magical Worlds of Harry Potter: A Treasury of Myths, Legends, and Fascinating Facts': 941,
#  'The Two Pearls of Wisdom': 942,
#  'The Lightning Thief': 943,
#  'Bleachers': 944,
#  'American Sniper: The Autobiography of the Most Lethal Sniper in U.S. Military History': 945,
#  '花ざかりの君たちへ 1': 946,
#  'The Mane Event': 947,
#  'Peony in Love': 948,
#  'Hidden ': 949,
#  'The Joy of Cooking': 950,
#  'A Confederacy of Dunces': 951,
#  'Honor Among Enemies': 952,
#  'Diane Arbus: An Aperture Monograph': 953,
#  'Fablehaven': 954,
#  'The Archived': 955,
#  'The Rumor': 956,
#  'Microserfs': 957,
#  'Seeing Redd': 958,
#  'Blood Red Road ': 959,
#  'We3': 960,
#  'The Face of Fear': 961,
#  '青の祓魔師 1': 962,
#  'The Drop': 963,
#  'An Anthropologist on Mars: Seven Paradoxical Tales': 964,
#  'The Women of Brewster Place': 965,
#  'The Greatest Generation': 966,
#  'Night World, No. 1': 967,
#  'The Obsession': 968,
#  'Big Nate on a Roll': 969,
#  'Succubus Blues': 970,
#  '午後の曳航 [Gogo no eikō]': 971,
#  "Princeps' Fury": 972,
#  'The Last Straw': 973,
#  'Abducted': 974,
#  'Dead Wake: The Last Crossing of the Lusitania': 975,
#  'Books of Blood: Volumes 1-3': 976,
#  'Unfamiliar Fishes': 977,
#  'Georgiana: Duchess of Devonshire': 978,
#  'Afterburn': 979,
#  'City of Thieves': 980,
#  'The Thousand Names': 981,
#  'Kiss the Dead': 982,
#  'International Flavor': 983,
#  'The Areas of My Expertise': 984,
#  'Baby Proof': 985,
#  'Welcome to Dead House': 986,
#  'Dragons of Summer Flame': 987,
#  'Heart of Darkness': 988,
#  'The Mauritius Command': 989,
#  'This is Not My Hat': 990,
#  'Blockade Billy': 991,
#  'The Ruby in the Smoke': 992,
#  'Wielding a Red Sword': 993,
#  'The 21 Irrefutable Laws of Leadership': 994,
#  'The Innovators: How a Group of Inventors, Hackers, Geniuses and Geeks Created the Digital Revolution': 995,
#  'Hiroshima': 996,
#  'How Music Works': 997,
#  'The Shawshank Redemption': 998,
#  'Essays and Poems': 999,
#  'Claim Me': 1000,
#  ...}

# %%
import tensorflow as tf
from tensorflow.keras import layers

import pandas as pd
import numpy
import random
from torch import nn
import torch
from torch.nn import functional as F
from torch import nn
import numpy as np
import collections
import string
import io
import json
import codecs

from thefuzz import fuzz
from thefuzz import process
from gensim.models.word2vec import Word2Vec
import gensim.downloader as gensim_api
import nltk
# Out:
# /home/theo/anaconda3/envs/prawn/lib/python3.7/site-packages/thefuzz/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']
# Stopwords to filter out. This list could be made more comprehensive

# %% [markdown]
# ## Load in our query embedder as well as other helpful files

# %%
#I don't think notebooks lets you just import a single function or class from another file, so we have to redefine
#the model class in order to load our trained query embedder
class TransformerEmbed(torch.nn.Module):
    '''
    TransformerEncoder for word embeddings. Since the synthetic queries are generated with out any type of order,
    we don't use a positional encoding.
    '''
    def __init__(self, in_dim, out_dim, transformer_dim=512):
        super(TransformerEmbed, self).__init__()
        
        encoder_layer = nn.TransformerEncoderLayer(d_model=transformer_dim, nhead=8,batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=3)
        
        self.initial = nn.Linear(in_dim,transformer_dim)
        self.final = nn.Linear(transformer_dim, out_dim)
        self.float()
    def call(self, inputs):
        x = self.initial(inputs)
        x = self.transformer_encoder(x)
        x = torch.mean(x,dim=1)
        x = nn.Sigmoid()(x)
        x = self.final(x)

        return x
        
transformer = TransformerEmbed(100,80)
checkpoint = 'https://github.com/tsteternlieb/BookRec/blob/main/research/query_model'
transformer.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint))
# Out:
# Downloading: "https://github.com/tsteternlieb/BookRec/blob/main/research/query_model" to /home/theo/.cache/torch/hub/checkpoints/query_model
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_384378/544609535.py in <module>
#      26 transformer = TransformerEmbed(100,80)
#      27 checkpoint = 'https://github.com/tsteternlieb/BookRec/blob/main/research/query_model'
# ---> 28 transformer.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint))
#
# ~/anaconda3/envs/prawn/lib/python3.7/site-packages/torch/hub.py in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash, file_name)
#     569             r = HASH_REGEX.search(filename)  # r is Optional[Match[str]]
#     570             hash_prefix = r.group(1) if r else None
# --> 571         download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#     572
#     573     if _is_legacy_zip_format(cached_file):
#
# ~/anaconda3/envs/prawn/lib/python3.7/site-packages/torch/hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     455             sha256 = hashlib.sha256()
#     456         with tqdm(total=file_size, disable=not progress,
# --> 457                   unit='B', unit_scale=True, unit_divisor=1024) as pbar:
#     458             while True:
#     459                 buffer = u.read(8192)
#
# ~/anaconda3/envs/prawn/lib/python3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# ~/anaconda3/envs/prawn/lib/python3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     114         if IProgress is None:  # #187 #451 #558 #872
#     115             raise ImportError(
# --> 116                 "IProgress not found. Please update jupyter and ipywidgets."
#     117                 " See https://ipywidgets.readthedocs.io/en/stable"
#     118                 "/user_install.html")
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# with open('most_popular_title_in_order') as json_file:
#     most_popular_title_in_order = json.load(json_file)

# with open('dict.json') as json_file:
#     correct_word_dict = json.load(json_file)
    
# with open('book_to_int.json') as json_file:
#     book_to_int = json.load(json_file)
    
# with open('int_to_book.json') as json_file:
#     int_to_book = json.load(json_file)
    
# with open('book_id_to_correct_title.json') as json_file:
#     book_id_to_correct_title = json.load(json_file)
    
# with open('incorrect_title_to_book_id.json') as json_file:
#     incorrect_title_to_book_id = json.load(json_file)
    
# with open('int_to_weight.json') as json_file:
#     temp = json.load(json_file)
# int_to_weight = {int(k):np.asarray(v) for k,v in temp.items()}

# corpus = gensim_api.load('text8')
# model = Word2Vec(corpus)

# %%
class VectorWrapper():
    '''
    class which wraps operations in the vector space
    so we never have to think about it in the main search class.
    '''
    def __init__(self,int_to_vector_dict, book_to_int, int_to_book):
        self.int_to_vector_dict = int_to_vector_dict
        self.book_to_int = book_to_int
        self.int_to_book = int_to_book
        
        #We are defining cosine similarity as the distance metric. This is just the normed dot product.
        self.scoring_fxn = nn.CosineSimilarity(dim=1, eps=1e-6) 
        self.vector_tensor = self.__get_vectors_as_tensors()
        
    def title_to_vector(self,title):
        book_int = self.int_to_book[title]
        
    #function for combing vectors into a tensor for fast distance calculation
    def __get_vectors_as_tensors(self):
        vector_tensor = []
        for i in range(len(self.book_to_int)):
            vector_tensor.append(self.int_to_vector_dict[i+1])
        
        return torch.tensor(vector_tensor)     
        
    def __compute_distance(self,vector1,vector2):
        if len(vector1.shape) == 1: 
            vector1 = torch.unsqueeze(vector1, dim = 0)
        
        if len(vector2.shape) == 1:
            vector2 = torch.unsqueeze(vector2, dim = 0)
        
        return self.scoring_fxn(vector1,vector2)
    
    def compute_nearest_booksV(self,vector,num):
        l = list(self.__compute_nearest_vectors(vector,num))
        return [self.int_to_book[str(int(i)+1)] for i in l]
        
    def compute_nearest_booksT(self,title,num):
        book_int = self.book_to_int[title]
        vector = torch.tensor(self.int_to_vector_dict[book_int])
        l = list(self.__compute_nearest_vectors(vector,num))
        return [self.int_to_book[str(int(i)+1)] for i in l]
        
    # stack the vector we're concerned with so that we can compute distances in parallel. Yay pytorch!     
    def __compute_nearest_vectors(self,vector,num):
        if len(vector.shape) == 1:
            vector = torch.unsqueeze(vector, dim = 0)
            
        __vector_stack = torch.cat([vector for _ in range(len(self.book_to_int))])
        
        scores = self.scoring_fxn(__vector_stack,self.vector_tensor)
        return torch.topk(scores,num,sorted=True)[1]
        
    def compute_matches_from_vector(self,vector):
        return self.__compute_nearest_vector(vector)

# %%
class SearchAlgo():
    '''class for handling logic of searches'''
    def __init__(self, book_vectors, w2v, query_model, fuzzy_cutoff, book_to_int):
        self.past_searches = []
        self.vector_wrapper = book_vectors
        self.fuzzy_cutoff = fuzzy_cutoff      
        self.titles = book_to_int.keys()
        self.book_to_int = book_to_int
        self.w2v = w2v
        self.query_model = query_model
        self.tokenizer = nltk.RegexpTokenizer(r"\w+")
        with open('most_popular_title_in_order') as json_file:
            self.most_popular_title_in_order = json.load(json_file)
    def get_nearest_books(self,vector,num):
        return self.vector_wrapper.compute_nearest_booksV(vector,num)
    
    # This function handles queries which weren't matched with titles.
    # It first calls __parse_query which deals with cleaning up the query. 
    # This intails filtering out stop words as well as words which the word2vec model doesn't know about
    
    def query_to_language_model(self, query, num):
        query, success = self.__parse_query(query)
        if not success:
            return None, False
        
        
        query = torch.tensor([[self.w2v.wv[q] for q in query]])
        vector = self.query_model.call(query)
        
        books = self.get_nearest_books(vector, num)
        return books, True
        
    def __parse_query(self, query):
        query = self.tokenizer.tokenize(query)
        query = [word.lower() for word in query if (word.lower() not in stopwords and word.lower() in self.w2v.wv.key_to_index.keys())]
        
        return(query,len(query)>0)
    
    # checks to see for matches on titles. 
    # This would need more engineering to make sure your not matching when you dont want to be.
    def __check_titles(self,query):
        print(query)
        for title in self.most_popular_title_in_order:
            if type(title) == str:
                if query.lower() in title.lower():
                    return title
        else:
            return None
            
            
    # main method which mostly just handles the logic, nothing so special
    def make_query(self, query, num = 5):
        #no searching by author!
        title_match = self.__check_titles(query)
        if title_match:
            #print('title found')
            return self.vector_wrapper.compute_nearest_booksT(title_match, num)
            
        else:
            books,success = self.query_to_language_model(query, num)
            if not success:
                return ["You entered a confusing word! No good recomendations..."]
            return books

# %%
class FinalWrapper():
    def __init__(self):
        corpus = gensim_api.load('text8')
        self.w2v = model = Word2Vec(corpus)
        self.__init_files()
        self.stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']
        self.vectorWrapper = VectorWrapper(self.int_to_weight,self.book_to_int,self.int_to_book)        
        self.search = SearchAlgo(self.vectorWrapper,self.w2v,self.transformer, .8, self.book_to_int)
        
        
    def __init_files(self):
#         with open('most_popular_title_in_order') as json_file:
#             self.most_popular_title_in_order = json.load(json_file)
        
        urls = ['https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/book_to_int.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/dict.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/book_to_int.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/int_to_book.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/book_id_to_correct_title.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/incorrect_title_to_book_id.json',
                'https://raw.githubusercontent.com/tsteternlieb/BookRec/main/research/int_to_weight.json',
               ]
                
                
                
        resp = requests.get(url[0])
        self.most_populate_title_in_order = json.loads(resp.text)

        with open('dict.json') as json_file:
            self.correct_word_dict = json.load(json_file)

        with open('book_to_int.json') as json_file:
            self.book_to_int = json.load(json_file)

        with open('int_to_book.json') as json_file:
            self.int_to_book = json.load(json_file)

        with open('book_id_to_correct_title.json') as json_file:
            self.book_id_to_correct_title = json.load(json_file)

        with open('incorrect_title_to_book_id.json') as json_file:
            self.incorrect_title_to_book_id = json.load(json_file)

        with open('int_to_weight.json') as json_file:
            temp = json.load(json_file)
            
        self.int_to_weight = {int(k):np.asarray(v) for k,v in temp.items()}
        self.transformer = transformer = TransformerEmbed(100,80)
        self.transformer.load_state_dict(torch.load('./query_model'))
        
    def GetRecs(self, query):
        return self.search.make_query(query, 10)

# %%
fWrapper = FinalWrapper()

# %%
fWrapper.GetRecs('harry potter')
# Out:
# harry potter
# ["Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Half-Blood Prince',
#  'Harry Potter and the Deathly Hallows',
#  'Frostbite',
#  'Shadow Kiss',
#  'Blood Promise',
#  'Complete Harry Potter Boxed Set']

# %%
vectorWrapper = VectorWrapper(int_to_weight,book_to_int,int_to_book)
search = SearchAlgo(vectorWrapper,model,transformer, .8, book_to_int)

# %%
search.make_query('harry potter',10)
# Out:
# harry potter
# title found
# ["Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Half-Blood Prince',
#  'Harry Potter and the Deathly Hallows',
#  'Frostbite',
#  'Shadow Kiss',
#  'Blood Promise',
#  'Complete Harry Potter Boxed Set']
